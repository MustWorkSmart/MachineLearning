# %% [markdown]
# # spaCy
# # shown below: NER, dependency parsing, part of speech tagging

# %%
# !pip install spacy
#Download the English langugage model for spaCy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (0.20.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (2.11.1)
# Requirement already satisfied: jinja2 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from spacy) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: wrapt in /opt/miniconda3/envs/my-env/lib/python3.12/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (1.17.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 3.1 MB/s eta 0:00:00a 0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import spacy

#Load the English model
nlp = spacy.load("en_core_web_sm") #spacy.load - loads the English model and assigns it to variable nlp

#When you execute nlp = spacy.load('en'), spaCy downloads and loads the pre-trained English language model
#into memory and assigns it to the variable nlp.
#This pre-trained model contains information about word vectors, part-of-speech tags, syntactic dependencies, and other linguistic features necessary for various NLP tasks.

# %%
# NER
text = ("MyStore, Inc. is planning to open a new store in Santa Clara." 
        "John Doe, the CEO, will be speaking at the opening event.")
doc = nlp(text)
#extract names entities
entities = [(ent.text, ent.label_) for ent in doc.ents]
print("Named Entities:")
for ent, label in entities:
    print(f"{ent} - {label}")
# Out:
# Named Entities:
# MyStore, Inc. - ORG
# Santa Clara - GPE
# John Doe - PERSON

# %%
# dependency parsing
from spacy import displacy
text = "Your service is awesome!"
doc = nlp(text)
#visualize the dependency parse tree
displacy.render(doc, style="dep", jupyter=True, options={'distance':90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5c444be8bf9c429a8cdeb747feb830ba-0" class="displacy" width="410" height="182.0" direction="ltr" style="max-width: none; height: 182.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="92.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="92.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">service</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="92.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="92.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">awesome!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5c444be8bf9c429a8cdeb747feb830ba-0-0" stroke-width="2px" d="M70,47.0 C70,2.0 140.0,2.0 140.0,47.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5c444be8bf9c429a8cdeb747feb830ba-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,49.0 L62,37.0 78,37.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5c444be8bf9c429a8cdeb747feb830ba-0-1" stroke-width="2px" d="M160,47.0 C160,2.0 230.0,2.0 230.0,47.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5c444be8bf9c429a8cdeb747feb830ba-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160,49.0 L152,37.0 168,37.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5c444be8bf9c429a8cdeb747feb830ba-0-2" stroke-width="2px" d="M250,47.0 C250,2.0 320.0,2.0 320.0,47.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5c444be8bf9c429a8cdeb747feb830ba-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M320.0,49.0 L328.0,37.0 312.0,37.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# part of speech tagging
text = ("Your products are excellent." 
        "However, taking 3 whole days to get delivered to my home is a bit long.")
doc = nlp(text)
#extract parts-of-speech tags
pos_tags = [(token.text, token.pos_) for token in doc]
print("Parts-of-Speech Tags:")
for token, pos_tag in pos_tags:
    print(f"{token} - {pos_tag}")
# Out:
# Parts-of-Speech Tags:
# Your - PRON
# products - NOUN
# are - AUX
# excellent - ADJ
# . - PUNCT
# However - ADV
# , - PUNCT
# taking - VERB
# 3 - NUM
# whole - ADJ
# days - NOUN
# to - PART
# get - AUX
# delivered - VERB
# to - ADP
# my - PRON
# home - NOUN
# is - AUX
# a - DET
# bit - NOUN
# long - ADJ
# . - PUNCT
